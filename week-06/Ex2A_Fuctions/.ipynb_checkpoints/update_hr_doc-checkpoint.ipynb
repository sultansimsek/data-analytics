# %% [markdown]
# ## Lab 3. Employee data
# This lab exercise makes updates to information extracted from
# an employee database.

# %%
hr_list = [
('0123', 'HR', 'Rebecca Yang', '69000'),
('0121', 'IT', 'Mark Blick', '67000'),
('0068', 'IT', 'Kahna Larsen', '112000'),
('0234', 'OPS', 'Jim Smith', '54000')
]

# %%
hr_list[1] = ('0121', 'IT', 'Hawley Blick', '67000')
print(hr_list)
# Out:
# [('0123', 'HR', 'Rebecca Yang', '69000'), ('0121', 'IT', 'Hawley Blick', '67000'), ('0068', 'IT', 'Kahna Larsen', '112000'), ('0234', 'OPS', 'Jim Smith', '54000')]

# %% [raw]
# print(hr_list)

# %%
hr_list[3] = ('0234', 'CS', 'Jim Smith', '60000')

# %%
print(hr_list)
# Out:
# [('0123', 'HR', 'Rebecca Yang', '69000'), ('0121', 'IT', 'Hawley Blick', '67000'), ('0068', 'IT', 'Kahna Larsen', '112000'), ('0234', 'CS', 'Jim Smith', '60000')]

# %% [markdown]
# ### solution
# Since I cannot make direct changes in tuples I updated the whole tuple

# %%
for i in hr_list:
  print(" | ".join(i))
# Out:
# 0123 | HR | Rebecca Yang | 69000
# 0121 | IT | Hawley Blick | 67000
# 0068 | IT | Kahna Larsen | 112000
# 0234 | CS | Jim Smith | 60000

# %% [markdown]
# ### solution
# I used .join method to treat tuple components as a string and make the necessary update.

# %%
for i in hr_list:

    formatted_salary = f"${int(i[3]):,}"

    formatted_i = (
        i[0],
        i[1],
        i[2],
        formatted_salary
    )

    print(" | ".join(formatted_employee))
# Out:
# 0234 | CS | Jim Smith | $60,000
# 0234 | CS | Jim Smith | $60,000
# 0234 | CS | Jim Smith | $60,000
# 0234 | CS | Jim Smith | $60,000

# %% [markdown]
# ### solution
#  In order for it to be scalable I used for loop for every list item. After that I wanted to format the salary part into integer in order to make necessary changes. I used formatted string and format that with format specifier ":", and format value",". After I formatted salary part I added "$" sign to specify it is currency. At the end I repeated the formatting with "|" with join string method.
