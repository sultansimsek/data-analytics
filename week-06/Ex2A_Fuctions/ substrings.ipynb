# %% [markdown]
# # Exercise 2.A Using built-in functions
# ## Lab 1. Working with names – parsing strings

# %%
test_name = 'John Doe'

# %%
def parse_and_display(name):
    for i in range(len(name)):
     if name[i] == ' ': 
       first = name[:i]
       last = name[i+1:]
       print(f"Full Name: {name}")
       print(f"First Name: {first}")
       print(f"Last Name: {last}")

# %%
parse_and_display(test_name)
# Out:
# Full Name: John Doe
# First Name: John
# Last Name: Doe

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']
parse_and_display(test_list[2])
# Out:
# Full Name: Ken Penn
# First Name: Ken
# Last Name: Penn

# %%
parse_and_display('Sultan Simsek')
# Out:
# Full Name: Sultan Simsek
# First Name: Sultan
# Last Name: Simsek

# %%
        parts = name.split()
        
        first = parts[0]
        middle = parts [1]
        last = parts [2]
        
        print(f"Full Name: {name}")
        print(f"First Name: {first}")
        print(f"Middle Name: {middle}")
        print(f"Last Name: {last}")

# %%
parse_and_display2('Gabriel Garcia Marquez')
# Out:
# Full Name: Gabriel Garcia Marquez
# First Name: Gabriel
# Middle Name: Garcia
# Last Name: Marquez
